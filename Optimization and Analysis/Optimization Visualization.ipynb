# %% [markdown]
# ## Different layersizes and structures

# %%
import numpy as np
import os

rootpath = 'Optimization Results/Layerstructure/3 Layers'
results = []
structure = []
for file in os.listdir(rootpath):
    try:
        results.append(np.load(os.path.join(rootpath,file)))
        structure.append(file)
    except:
        pass
print(structure[6][0:-55])
# Out:
# CNN_16_96_128

# %%
# 3 LAYERS different layersizes

import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(11, 3), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
axs[0].plot(results[6][0], results[6][2], label=structure[6][0:-55]+' (GTNet)', linewidth=3.5)
axs[1].plot(results[6][0], results[6][1], label=structure[6][0:-55]+' (GTNet)', linewidth=3.5)

for i in [5,7,9]:
    axs[0].plot(results[i][0], results[i][2], label=structure[i][0:-55], alpha=0.5)
    axs[1].plot(results[i][0], results[i][1], label=structure[i][0:-55], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.96)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
#axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_3layers.png',dpi=500)
plt.show()

# %%
# 4 LAYERS

import numpy as np
import os

rootpath = 'Optimization Results/Layerstructure/4 Layers'
four_layer_results = []
four_layer_structure = []
for file in os.listdir(rootpath):
    try:
        four_layer_results.append(np.load(os.path.join(rootpath,file)))
        four_layer_structure.append(file)
    except:
        pass

# %%
# 4 LAYERS different layersizes

import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show best result
axs[0].plot(results[6][0], results[6][2], label=structure[6][0:-55], linewidth=2)
axs[1].plot(results[6][0], results[6][1], label=structure[6][0:-55], linewidth=2)

for i in range(0,3):
    axs[0].plot(four_layer_results[i][0], four_layer_results[i][2], label=four_layer_structure[i][0:-55], alpha=0.5)
    axs[1].plot(four_layer_results[i][0], four_layer_results[i][1], label=four_layer_structure[i][0:-55], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.96)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_4layers.png', dpi=500)
plt.show()

# %%
# 2 LAYERS

import numpy as np
import os

rootpath = 'Optimization Results/Layerstructure/2 Layers'
two_layer_results = []
two_layer_structure = []
for file in os.listdir(rootpath):
    try:
        two_layer_results.append(np.load(os.path.join(rootpath,file)))
        two_layer_structure.append(file)
    except:
        pass

# %%
# 2 LAYERS different layersizes

import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show best result
axs[0].plot(results[6][0], results[6][2], label=structure[6][0:-55], linewidth=2)
axs[1].plot(results[6][0], results[6][1], label=structure[6][0:-55], linewidth=2)

for i in range(0,3):
    axs[0].plot(two_layer_results[i][0], two_layer_results[i][2], label=two_layer_structure[i][0:-55], alpha=0.5)
    axs[1].plot(two_layer_results[i][0], two_layer_results[i][1], label=two_layer_structure[i][0:-55], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.96)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_2layers.png', dpi=500)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True, sharey=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show best result
axs[0].plot(results[6][0], results[6][1], label=structure[6][0:-55]+' (GTNet)', linewidth=3.5)
axs[1].plot(results[6][0], results[6][1], label=structure[6][0:-55]+' (GTNet)', linewidth=3.5)

for i in range(0,3):
    axs[1].plot(four_layer_results[i][0], four_layer_results[i][1], label=four_layer_structure[i][0:-55], alpha=0.5)
    axs[0].plot(two_layer_results[i][0], two_layer_results[i][1], label=two_layer_structure[i][0:-55], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

axs[0].set_title('Two Conv2D layers')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation loss')
axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs[1].set_yticks([])

axs[1].set_title('Four Conv2D layers')
axs[1].set_xlabel('Epoch')
#axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss_2+4layers.png', dpi=500)
plt.show()

# %% [markdown]
# # Denslayer variation

# %%
# dense 

import numpy as np
import os

rootpath = 'Optimization Results/Denselayer/'
dense_layer_results = []
dense_layer_structure = []
for file in os.listdir(rootpath):
    try:
        dense_layer_results.append(np.load(os.path.join(rootpath,file)))
        dense_layer_structure.append(file)
    except:
        pass

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show (best) standard result
#axs[0].plot(dense_layer_results[0][0], dense_layer_results[0][2], label=dense_layer_structure[0][14:-55], linewidth=2)
#axs[1].plot(dense_layer_results[0][0], dense_layer_results[0][1], label=dense_layer_structure[0][14:-55], linewidth=2)
axs[0].plot(results[6][0], results[6][2], label='Dense_256', linewidth=2)
axs[1].plot(results[6][0], results[6][1], label='Dense_256', linewidth=2)
for i in range(1,4):
    axs[0].plot(dense_layer_results[i][0], dense_layer_results[i][2], label=dense_layer_structure[i][14:-55], alpha=0.5)
    axs[1].plot(dense_layer_results[i][0], dense_layer_results[i][1], label=dense_layer_structure[i][14:-55], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.96)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_Denselayers.png', dpi=500)
plt.show()

# %% [markdown]
# # Activationfunctions

# %%
# activations

import numpy as np
import os

rootpath = 'Optimization Results/Activation functions/'
activation_results = []
activation_structure = []
for file in os.listdir(rootpath):
    try:
        activation_results.append(np.load(os.path.join(rootpath,file)))
        activation_structure.append(file)
    except:
        pass
print(activation_structure[2][14:-50])
# Out:
# leakyRelu

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show (best) standard result
#axs[0].plot(dense_layer_results[0][0], dense_layer_results[0][2], label=dense_layer_structure[0][14:-55], linewidth=2)
#axs[1].plot(dense_layer_results[0][0], dense_layer_results[0][1], label=dense_layer_structure[0][14:-55], linewidth=2)
axs[0].plot(results[6][0], results[6][2], label='relu', linewidth=2)
axs[1].plot(results[6][0], results[6][1], label='relu', linewidth=2)
for i in range(1,4):
    axs[0].plot(activation_results[i][0], activation_results[i][2], label=activation_structure[i][14:-50], alpha=0.5)
    axs[1].plot(activation_results[i][0], activation_results[i][1], label=activation_structure[i][14:-50], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.90)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.3,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_activations.png', dpi=500)
plt.show()

# %% [markdown]
# # Padding

# %%
# padding

import numpy as np
import os

rootpath = 'Optimization Results/Padding/'
padding_results = []
padding_structure = []
for file in os.listdir(rootpath):
    try:
        padding_results.append(np.load(os.path.join(rootpath,file)))
        padding_structure.append(file)
    except:
        pass
print(padding_structure[1][-8:-4])
# Out:
# same

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show (best) standard result
#axs[0].plot(dense_layer_results[0][0], dense_layer_results[0][2], label=dense_layer_structure[0][14:-55], linewidth=2)
#axs[1].plot(dense_layer_results[0][0], dense_layer_results[0][1], label=dense_layer_structure[0][14:-55], linewidth=2)
axs[0].plot(results[6][0], results[6][2], label='same', linewidth=2)
axs[1].plot(results[6][0], results[6][1], label='same', linewidth=2)

axs[0].plot(padding_results[0][0], padding_results[0][2], label='valid (no overlap)', alpha=0.5)
axs[1].plot(padding_results[0][0], padding_results[0][1], label='valid (no overlap)', alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.96)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_padding.png', dpi=500)
plt.show()

# %% [markdown]
# # Optimizers

# %%
# OPTIMIZERS

import numpy as np
import os

rootpath = 'Optimization Results/optimizers/'
optimizer_results = []
optimizer_structure = []
for file in os.listdir(rootpath):
    try:
        optimizer_results.append(np.load(os.path.join(rootpath,file)))
        optimizer_structure.append(file)
    except:
        pass
print(optimizer_structure[1][19:-42])
# Out:
# Adam

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show (best) standard result
#axs[0].plot(dense_layer_results[0][0], dense_layer_results[0][2], label=dense_layer_structure[0][14:-55], linewidth=2)
#axs[1].plot(dense_layer_results[0][0], dense_layer_results[0][1], label=dense_layer_structure[0][14:-55], linewidth=2)
axs[0].plot(results[6][0], results[6][2], label='relu', linewidth=2)
axs[1].plot(results[6][0], results[6][1], label='relu', linewidth=2)
for i in range(0,3):
    axs[0].plot(optimizer_results[i][0], optimizer_results[i][2], label=optimizer_structure[i][19:-42], alpha=0.5)
    axs[1].plot(optimizer_results[i][0], optimizer_results[i][1], label=optimizer_structure[i][19:-42], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=1.0,ymin=0.90)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[0].set_title('Validation accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation accuracy')
#axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.3,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

#axs[1].set_title('Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss+Accuracy_optimizers.png', dpi=500)
plt.show()

# %% [markdown]
# # Optimizer + activation

# %%
import numpy as np
import os

rootpath = 'Optimization Results/optimizers/'
optimizer_results = []
optimizer_structure = []
for file in os.listdir(rootpath):
    try:
        optimizer_results.append(np.load(os.path.join(rootpath,file)))
        optimizer_structure.append(file)
    except:
        pass
print(optimizer_structure[1][19:-42])
# Out:
# Adam

# %%
# activations

import numpy as np
import os

rootpath = 'Optimization Results/Activation functions/'
activation_results = []
activation_structure = []
for file in os.listdir(rootpath):
    try:
        activation_results.append(np.load(os.path.join(rootpath,file)))
        activation_structure.append(file)
    except:
        pass
print(activation_structure[2][14:-50])
# Out:
# leakyRelu

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True, sharey=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show best result
axs[0].plot(results[6][0], results[6][1], label='RMSprop (GTNet)', linewidth=3.5)
axs[1].plot(results[6][0], results[6][1], label='relu (GTNet)', linewidth=3.5)

for i in range(0,3):
    axs[0].plot(optimizer_results[i][0], optimizer_results[i][1], label=optimizer_structure[i][19:-42], alpha=0.5)
for i in range(1,4):
    axs[1].plot(activation_results[i][0], activation_results[i][1], label=activation_structure[i][14:-50], alpha=0.5)
    
axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

axs[0].set_title('Different optimizers')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation loss')
axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs[1].set_yticks([])

axs[1].set_title('Different activation functions')
axs[1].set_xlabel('Epoch')
#axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss_opt+activ.png', dpi=500)
plt.show()

# %% [markdown]
# # Padding+Dense

# %%
# padding

import numpy as np
import os

rootpath = 'Optimization Results/Padding/'
padding_results = []
padding_structure = []
for file in os.listdir(rootpath):
    try:
        padding_results.append(np.load(os.path.join(rootpath,file)))
        padding_structure.append(file)
    except:
        pass
print(padding_structure[1][-8:-4])
# Out:
# same

# %%
# dense 

import numpy as np
import os

rootpath = 'Optimization Results/Denselayer/'
dense_layer_results = []
dense_layer_structure = []
for file in os.listdir(rootpath):
    try:
        dense_layer_results.append(np.load(os.path.join(rootpath,file)))
        dense_layer_structure.append(file)
    except:
        pass

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), constrained_layout=True, sharey=True)

#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
axs = axs.ravel()

axs[0].grid(True)
# show best result
axs[0].plot(results[6][0], results[6][1], label='Zero Padding (GTNet)', linewidth=3.5)
axs[1].plot(results[6][0], results[6][1], label='Dense_256 (GTNet)', linewidth=3.5)

for i in range(1,4):
    axs[1].plot(dense_layer_results[i][0], dense_layer_results[i][1], label=dense_layer_structure[i][14:-55], alpha=0.5)


axs[0].plot(padding_results[0][0], padding_results[0][1], label='No Padding', alpha=0.5)


axs[0].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[0].set_xlim(xmax=11,xmin=0)
axs[0].set_ylim(ymax=0.2,ymin=0)
#axs.set_yticks(np.arange(0,0.07,0.01))

axs[0].set_title('Padding')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Validation loss')
axs[0].legend()

axs[1].grid(True)
#axs[1].plot(results[0], results[1])
axs[1].set_xticks(np.arange(1,11))#, rotation='vertical')
axs[1].set_xlim(xmax=11,xmin=0)
axs[1].set_ylim(ymax=0.2,ymin=0)
#axs[1].set_yticks([])

axs[1].set_title('Denselayer variations')
axs[1].set_xlabel('Epoch')
#axs[1].set_ylabel('Validation loss')
axs[1].legend()
plt.legend()
[0,1,2,4,5,10,13]


plt.savefig('ValidationLoss_pad+dense.png', dpi=500)
plt.show()
